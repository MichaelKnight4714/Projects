# %% [markdown]
# # Cheese Recommender

# %% [markdown]
# ## EDA and Cleaning

# %%
import pandas as pd 
import numpy as np
import requests
from bs4 import BeautifulSoup
import time
import unicodedata

# %% [markdown]
# Recommending cheese based on blah blah blah...  Cheese.com very lenient API

# %%
#read cheese_posts.csv into 'train'
chz_df3 = pd.read_csv('./data/clean_big_cheese_w_names.csv')

# %%
chz_df3
# Out:
#                          Name                             Made from  \
# 0            Abbaye de Belloc  unpasteurized cow's and sheep's milk
# 1            Abbaye de Belval                            cow's milk
# 2           Abbaye de Citeaux              unpasteurized cow's milk
# 3          Abbaye de Timadeuc                pasteurized cow's milk
# 4     Abbaye du Mont des Cats                pasteurized cow's milk
# ...                       ...                                   ...
# 1823             Zelu Koloria              pasteurized sheep's milk
# 1824  Zigljen Iz Extra Mature    pasteurized cow's and sheep's milk
# 1825         Zigljen Iz Mosta    pasteurized cow's and sheep's milk
# 1826                   Zimbro                                   NaN
# 1827                  Zwitser              unpasteurized cow's milk
#
#      Country of origin                      Region Family  \
# 0               France                 Pays Basque    NaN
# ...

# %%
chz_df3['Synonyms'].unique().tolist()
# Out:
# ['Abbaye Notre-Dame de Belloc',
#  nan,
#  "English Cheddar with Caramelized Onions, Caramelised Onion Cheddar, Abbot's Gold Cheddar with Caramelised Onion",
#  'Affineur Walo red wine Sennechäs, Affineur Walo Red Wine Farmer',
#  'Reishi Mushroom Aged Cashew Cheese, Truffle Aged Cashew Cheese, Smoked Aged Cashew Cheese, Cajun Aged Cashew Cheese',
#  'Jong belegen Gouda, Belegen Gouda, Extra belegen Gouda, Oud Gouda, Overjarig Gouda, Five-Year Aged Gouda, Gouda, Aged Four Years',
#  'Kumis',
#  "Ashen Aisy, Cendre d'Aisy",
#  'Woodside Allium Piper, Woodside Chevre - Allium Piper',
#  'Vorarlberg Alpine cheese 3-5 months',
#  'Vorarlberg Alpine cheese 6-9 months',
#  'Alpenrebell',
#  'Yellow cheese from the lower Beira',
#  'Arabella',
#  "L'Ami du Chambertin",
#  "Amu, l'Amou",
#  'Fresh Anari, Dry Anari',
#  'Añejo, Queso Añejo',
#  'Red Anster',
#  'Anthotyro Fresco, Mizithra',
#  'Anthotiro, Fresh Anthotyro',
#  'Promontory Apple Walnut Smoked , Smoked Apple Walnut',
# ...

# %%
# took Adi Bronshtein's function for conducting exploratory data analysis and added spaces between each eda test
# using blank print statesments and \n for easier readability
def eda(dataframe):
    print("missing values: \n{}".format(dataframe.isnull().sum()))
    print()
    print("dataframe index: \n{}".format(dataframe.index))
    print()
    print("dataframe types: \n{}".format(dataframe.dtypes))
    print()
    print("dataframe shape: \n{}".format(dataframe.shape))
    print()
    print("dataframe describe: \n{}".format(dataframe.describe()))
    print()

    print("number of unique values in each column: ")
    for item in dataframe:
        print(item)
        print(dataframe[item].nunique())

# %%
eda(chz_df3)
# Out:
# missing values:
# Name                              0
# Made from                        55
# Country of origin                17
# Region                          238
# Family                         1034
# Type                             24
# Fat content (in dry matter)    1818
# Fat content                    1235
# Calcium content                1780
# Texture                         105
# Rind                            238
# Colour                          175
# Flavour                          94
# Aroma                           354
# Vegetarian                      527
# Producers                       402
# Synonyms                       1453
# Alternative spellings          1622
# dtype: int64
#
# dataframe index:
# RangeIndex(start=0, stop=1828, step=1)
#
# dataframe types:
# Name                           object
# Made from                      object
# Country of origin              object
# Region                         object
# Family                         object
# ...

# %%
# drop columns that provide no value to this project
chz_df3.drop(columns=['Fat content (in dry matter)', 'Synonyms', 'Alternative spellings'], inplace=True)

# %% [markdown]
# ## why not drop color?
# "... so why are some cheeses yellow and orange? Originally, cheese could be different shades of white, yellow or orange, depending on when it was made and what the cows had eaten. In the spring and summer, cows ate fresh grass and other plants that contained beta-carotene and vitamin D. This resulted in yellow cheese. In the winter, cows ate hay instead, so the cheese was pale. Cheese produced in the spring and summer was more desirable, so cheesemakers began dyeing their cheese. Now it's become more of a tradition to dye certain types of cheeses."
#
# from https://science.howstuffworks.com/innovation/edible-innovations/cheese.htm

# %%
eda(chz_df3)
# Out:
# missing values:
# Name                    0
# Made from              55
# Country of origin      17
# Region                238
# Family               1034
# Type                   24
# Fat content          1235
# Calcium content      1780
# Texture               105
# Rind                  238
# Colour                175
# Flavour                94
# Aroma                 354
# Vegetarian            527
# Producers             402
# dtype: int64
#
# dataframe index:
# RangeIndex(start=0, stop=1828, step=1)
#
# dataframe types:
# Name                 object
# Made from            object
# Country of origin    object
# Region               object
# Family               object
# Type                 object
# Fat content          object
# Calcium content      object
# Texture              object
# Rind                 object
# Colour               object
# Flavour              object
# Aroma                object
# Vegetarian           object
# Producers            object
# ...

# %%
chz_df3['Family'].unique()
# Out:
# array([nan, 'Cheddar', 'Tomme', 'Feta', 'Blue', 'Swiss Cheese', 'Gouda',
#        'Mozzarella', 'Cottage', 'Pasta filata', 'Brie', 'Gruyere',
#        'Parmesan', 'Camembert', 'Monterey Jack', 'Caciotta', 'Pecorino',
#        'Gorgonzola', 'Raclette', 'Cornish', 'Havarti', 'Italian Cheese',
#        'Producers: Tiernan Family Farm', 'Saint-Paulin',
#        'Producers: Crawford Family Farms',
#        'Producers: Jasper Hill Farm, Scholten Family Farm'], dtype=object)

# %%
url2 = 'https://od-do.agr.gc.ca/canadianCheeseDirectory.json'

# %%
req2 = requests.get(url2)

# %%
req2
# Out:
# <Response [200]>

# %%
canada_chz = req2.json()

# %%
canada_chz
# Out:
# {'CheeseDirectory': [{'CheeseId': '228',
#    'CheeseNameEn': '',
#    'CheeseNameFr': 'Sieur de Duplessis (Le)',
#    'ManufacturerNameEn': '',
#    'ManufacturerNameFr': 'Fromages la faim de loup',
#    'ManufacturerProvCode': 'NB',
#    'ManufacturingTypeEn': 'Farmstead',
#    'ManufacturingTypeFr': 'Fermière',
#    'WebSiteEn': '',
#    'WebSiteFr': '',
#    'FatContentPercent': '24.2',
#    'MoisturePercent': '47',
#    'ParticularitiesEn': '',
#    'ParticularitiesFr': '',
#    'FlavourEn': 'Sharp, lactic',
#    'FlavourFr': 'Marquée et lactée',
#    'CharacteristicsEn': 'Uncooked',
#    'CharacteristicsFr': 'Pâte non cuite',
#    'RipeningEn': '9 Months',
#    'RipeningFr': '9 mois',
#    'Organic': '0',
#    'CategoryTypeEn': 'Firm Cheese',
#    'CategoryTypeFr': 'Pâte ferme',
#    'MilkTypeEn': 'Ewe',
#    'MilkTypeFr': 'Brebis',
#    'MilkTreatmentTypeEn': 'Raw Milk',
#    'MilkTreatmentTypeFr': 'Lait cru',
#    'RindTypeEn': 'Washed Rind',
# ...

# %%
canada_chz['CheeseDirectory']
# Out:
# [{'CheeseId': '228',
#   'CheeseNameEn': '',
#   'CheeseNameFr': 'Sieur de Duplessis (Le)',
#   'ManufacturerNameEn': '',
#   'ManufacturerNameFr': 'Fromages la faim de loup',
#   'ManufacturerProvCode': 'NB',
#   'ManufacturingTypeEn': 'Farmstead',
#   'ManufacturingTypeFr': 'Fermière',
#   'WebSiteEn': '',
#   'WebSiteFr': '',
#   'FatContentPercent': '24.2',
#   'MoisturePercent': '47',
#   'ParticularitiesEn': '',
#   'ParticularitiesFr': '',
#   'FlavourEn': 'Sharp, lactic',
#   'FlavourFr': 'Marquée et lactée',
#   'CharacteristicsEn': 'Uncooked',
#   'CharacteristicsFr': 'Pâte non cuite',
#   'RipeningEn': '9 Months',
#   'RipeningFr': '9 mois',
#   'Organic': '0',
#   'CategoryTypeEn': 'Firm Cheese',
#   'CategoryTypeFr': 'Pâte ferme',
#   'MilkTypeEn': 'Ewe',
#   'MilkTypeFr': 'Brebis',
#   'MilkTreatmentTypeEn': 'Raw Milk',
#   'MilkTreatmentTypeFr': 'Lait cru',
#   'RindTypeEn': 'Washed Rind',
#   'RindTypeFr': 'Croûte lavée',
# ...

# %%
#read cheese_posts.csv into 'train'
can_chz = pd.read_csv('./data/canadianCheeseDirectory.csv')

# %%
can_chz.T
# Out:
#                                           0     \
# CheeseId                                   228
# CheeseNameEn                               NaN
# CheeseNameFr           Sieur de Duplessis (Le)
# ManufacturerNameEn                         NaN
# ManufacturerNameFr    Fromages la faim de loup
# ManufacturerProvCode                        NB
# ManufacturingTypeEn                  Farmstead
# ManufacturingTypeFr                   Fermière
# WebSiteEn                                  NaN
# WebSiteFr                                  NaN
# FatContentPercent                         24.2
# MoisturePercent                             47
# ParticularitiesEn                          NaN
# ParticularitiesFr                          NaN
# FlavourEn                        Sharp, lactic
# FlavourFr                    Marquée et lactée
# CharacteristicsEn                     Uncooked
# CharacteristicsFr               Pâte non cuite
# RipeningEn                            9 Months
# ...

# %%
eda(can_chz)
# Out:
# missing values:
# CheeseId                  0
# CheeseNameEn            867
# CheeseNameFr            368
# ManufacturerNameEn      771
# ManufacturerNameFr      487
# ManufacturerProvCode      0
# ManufacturingTypeEn       0
# ManufacturingTypeFr       0
# WebSiteEn               576
# WebSiteFr               667
# FatContentPercent       409
# MoisturePercent         420
# ParticularitiesEn       946
# ParticularitiesFr       947
# FlavourEn               506
# FlavourFr               509
# CharacteristicsEn       689
# CharacteristicsFr       691
# RipeningEn              709
# RipeningFr              711
# Organic                   0
# CategoryTypeEn          144
# CategoryTypeFr          144
# MilkTypeEn               21
# MilkTypeFr               21
# MilkTreatmentTypeEn     215
# MilkTreatmentTypeFr     215
# RindTypeEn              594
# RindTypeFr              594
# LastUpdateDate            0
# dtype: int64
#
# dataframe index:
# RangeIndex(start=0, stop=1451, step=1)
#
# ...

# %%
can_chz['CheeseNameEn'].unique()
# Out:
# array([nan, 'Provolone Sette Fette (Tre-Stelle)',
#        'Paneer (Northumberland Co-operative)', 'Goat Brie (Woolwich)',
#        'Goat Cheddar (Woolwich)', 'Goat Mozarella (Woolwich)',
#        'Goat Feta (Woolwich)', 'Leoni-Grana',
#        'Gouda (Jerseyland Organic)', 'Cheddar (Jerseyland Organic)',
#        'Grana (Jerseyland Organic)', 'Feta (Jerseyland Organic)',
#        'Udderly Organic Goat Gouda (Jerseyland Organic)',
#        'Udderly Organic Goat Feta (Jerseyland Organic)', 'Madawaska',
#        'Cracked Pepper Verdelait', 'Cumin Verdelait',
#        'Garlic and Chive Verdelait', 'Wasabi Verdelait',
#        'Comox Camembert', 'Provolone (Silani)', 'Ricotta (Silani)',
#        'Gouda (Sylvan Star Ltd.)', 'Niagara Gold', 'Comfort Cream',
#        'Cheddar (Balderson)', "Gouda (That Dutchman's Farm)",
#        "Dragon's Breath", 'Feta (Black Diamond)', 'Dalhousie',
#        'Highland Blue', 'Flower Station', 'Snow Road', 'French Line',
# ...

# %%
can_chz['CheeseNameFr'].unique()
# Out:
# array(['Sieur de Duplessis (Le)', 'Tomme Le Champ Doré',
#        'Provolone Sette Fette (Tre-Stelle)', ..., 'Electric Blue',
#        'Hip Hop', 'Super Fresh Cheese Curds'], dtype=object)

# %%
can_chz['CheeseNameFr']#.iloc[item[0]]
# Out:
# 0                  Sieur de Duplessis (Le)
# 1                      Tomme Le Champ Doré
# 2       Provolone Sette Fette (Tre-Stelle)
# 3                           Geai Bleu (Le)
# 4                               Gamin (Le)
#                        ...
# 1446                              Knoydart
# 1447                               FRESK-O
# 1448                         Electric Blue
# 1449                               Hip Hop
# 1450              Super Fresh Cheese Curds
# Name: CheeseNameFr, Length: 1451, dtype: object

# %%
can_chz
# Out:
#       CheeseId                        CheeseNameEn  \
# 0          228                                 NaN
# 1          242                                 NaN
# 2          301  Provolone Sette Fette (Tre-Stelle)
# 3          303                                 NaN
# 4          319                                 NaN
# ...        ...                                 ...
# 1446      2387                            Knoydart
# 1447      2388                             FRESK-O
# 1448      2389                       Electric Blue
# 1449      2390                             Hip Hop
# 1450      2391            Super Fresh Cheese Curds
#
#                             CheeseNameFr       ManufacturerNameEn  \
# 0                Sieur de Duplessis (Le)                      NaN
# 1                    Tomme Le Champ Doré                      NaN
# 2     Provolone Sette Fette (Tre-Stelle)  Tre Stelle (Arla Foods)
# 3                         Geai Bleu (Le)                      NaN
# ...

# %%
can_chz['ManufacturingTypeEn'].unique()
# Out:
# array(['Farmstead', 'Industrial', 'Artisan'], dtype=object)

# %%
can_chz['ParticularitiesEn'].unique()
# Out:
# array([nan, 'Traditional Indian Cheese, also available : Light Paneer',
#        'Rennet free, ripens from the outside in',
#        'Medium Aged, rennet free', 'Rennet free',
#        'Roasted Red Pepper, Cranberry with Port, Mediterranean, Lemon poppy seed',
#        'Available : Plain, Garlic and dill, Mixed herb, Caraway, Cumin, Onion & garlic, Hemp',
#        'Available : Plain, onion and garlic, Jalapeno/Habenero, Leicester',
#        'Available : Plain or Sundried tomato and oregano and onion',
#        'The Royal Agricultural Winter Fair 1st Place',
#        'The Royal Agricultural Winter Fair 1st Place 2004',
#        'British Empire Cheese Show 2004 1st Place',
#        '2006 Canadian Grand Prix Finalist',
#        '2006 Canadian Cheese Grand Prix Category Champion "Pasta filata"',
#        '2006 Canadian Cheese Grand Prix Finalist',
#        '2006, 2009, 2011 Canadian Cheese Grand Prix Category Champion',
# ...

# %%
can_chz['MilkTreatmentTypeEn'].unique() # Thermisation is a cooking process less severe then pasteurization
# Out:
# array(['Raw Milk', 'Pasteurized', 'Thermised', nan], dtype=object)

# %%
# fill in all of the null values in the english columns with values from the corresponding french features
# then drop the french column, and rename the remaining columns

can_chz['CheeseNameEn'].fillna(can_chz['CheeseNameFr'], inplace=True)
can_chz['ManufacturerNameEn'].fillna(can_chz['ManufacturerNameFr'], inplace=True)
can_chz['ManufacturingTypeEn'].fillna(can_chz['ManufacturingTypeFr'], inplace=True)
can_chz['WebSiteEn'].fillna(can_chz['WebSiteFr'], inplace=True)
can_chz['ParticularitiesEn'].fillna(can_chz['ParticularitiesFr'], inplace=True)
can_chz['FlavourEn'].fillna(can_chz['FlavourFr'], inplace=True)
can_chz['CharacteristicsEn'].fillna(can_chz['CharacteristicsFr'], inplace=True)
can_chz['RipeningEn'].fillna(can_chz['RipeningFr'], inplace=True)
can_chz['CategoryTypeEn'].fillna(can_chz['CategoryTypeFr'], inplace=True)
can_chz['MilkTypeEn'].fillna(can_chz['MilkTypeFr'], inplace=True)
can_chz['MilkTreatmentTypeEn'].fillna(can_chz['MilkTreatmentTypeFr'], inplace=True)
can_chz['RindTypeEn'].fillna(can_chz['RindTypeFr'], inplace=True)


can_chz.drop(columns=['CheeseNameFr', 'ManufacturerNameFr', 'ManufacturingTypeFr', 
                      'WebSiteFr', 'ParticularitiesFr', 'FlavourFr', 'CharacteristicsFr', 'RipeningFr', 
                     'CategoryTypeFr', 'MilkTypeFr', 'MilkTreatmentTypeFr', 'RindTypeFr'], inplace=True)

can_chz.rename(columns={"CheeseNameEn": "Name", "ManufacturerNameEn": "Manufacturer", 
                        "ManufacturingTypeEn": "Source_Type", "WebSiteEn": "Website", 
                        "ParticularitiesEn": "Rando_Details", "FlavourEn": "Flavor", 
                        "CharacteristicsEn": "Characteristics", "RipeningEn": "Age", 
                        "CategoryTypeEn": "Category", "MilkTypeEn": "Animal",
                       "MilkTreatmentTypeEn": "Raw_or_Past", "RindTypeEn": "Rind", 
                       "ManufacturerProvCode": "Provence"}, inplace=True)

# %%
# drop columns that provide no value to this project
can_chz.drop(columns=['CheeseId', 'Website', 'LastUpdateDate'], inplace=True)

# %%
eda(can_chz)
# Out:
# missing values:
# Name                   0
# Manufacturer           0
# Provence               0
# Source_Type            0
# FatContentPercent    409
# MoisturePercent      420
# Rando_Details        945
# Flavor               505
# Characteristics      688
# Age                  709
# Organic                0
# Category             144
# Animal                21
# Raw_or_Past          215
# Rind                 594
# dtype: int64
#
# dataframe index:
# RangeIndex(start=0, stop=1451, step=1)
#
# dataframe types:
# Name                  object
# Manufacturer          object
# Provence              object
# Source_Type           object
# FatContentPercent    float64
# MoisturePercent      float64
# Rando_Details         object
# Flavor                object
# Characteristics       object
# Age                   object
# Organic                int64
# Category              object
# Animal                object
# Raw_or_Past           object
# Rind                  object
# ...

# %%
#save progress in csv
can_chz.to_csv('./data/canadian_cheese_part_clean.csv', index=False)

# %%
can_chz[can_chz['Animal'].isnull()]
# Out:
#                                                    Name  \
# 1204                                            Wig-Wam
# 1228                                           Mascaret
# 1231                                       Maudite (La)
# 1252                                         Crazy Goat
# 1276         Fromage à la Crème (Hilary's Fine Cheeses)
# 1277                      Quark (Hilary's Fine Cheeses)
# 1279                                         Sacré Bleu
# 1280                                        Valley Blue
# 1281                         Santa Lucia Fior' di Latte
# 1282  Santa Lucia Aged Parmesan (International Chees...
# 1283                                            Passati
# 1289        Olde Farmer Cheese (Little Qualicum Cheese)
# 1293         Farmstead Feta (Moonstruck Organic Cheese)
# 1326      Raclette (La Trappe à fromage de l'Outaouais)
# 1327  Farmer cheese (La trappe à formage de l'Outaou...
# 1328         Colby (La Trappe à fromage de l'Outaouais)
# ...

# %%
# set the dataframe to drop any rows where we don't know what animal the milk came from 
#can_chz = can_chz[can_chz['Animal'].notnull()].reset_index(drop=True)
    #### . WAAAAAIT MAYBE FILL WHEN I CAN FIND VIA RESEARCH???

# %%
can_chz.isnull().sum()
# Out:
# Name                   0
# Manufacturer           0
# Provence               0
# Source_Type            0
# FatContentPercent    409
# MoisturePercent      420
# Rando_Details        945
# Flavor               505
# Characteristics      688
# Age                  709
# Organic                0
# Category             144
# Animal                21
# Raw_or_Past          215
# Rind                 594
# dtype: int64

# %%
can_chz.shape
# Out:
# (1451, 15)

# %%
can_chz[can_chz['Name'] == 'Wig-Wam'].isnull().sum() # drop
# Out:
# Name                 0
# Manufacturer         0
# Provence             0
# Source_Type          0
# FatContentPercent    1
# MoisturePercent      1
# Rando_Details        1
# Flavor               1
# Characteristics      1
# Age                  1
# Organic              0
# Category             1
# Animal               1
# Raw_or_Past          1
# Rind                 1
# dtype: int64

# %%
can_chz
# Out:
#                                     Name              Manufacturer Provence  \
# 0                Sieur de Duplessis (Le)  Fromages la faim de loup       NB
# 1                    Tomme Le Champ Doré  Fromages la faim de loup       NB
# 2     Provolone Sette Fette (Tre-Stelle)   Tre Stelle (Arla Foods)       ON
# 3                         Geai Bleu (Le)  Fromages la faim de loup       NB
# 4                             Gamin (Le)  Fromages la faim de loup       NB
# ...                                  ...                       ...      ...
# 1446                            Knoydart      Knoydart Farm Cheese       NS
# 1447                             FRESK-O          Latin Foods Inc.       AB
# 1448                       Electric Blue       Blue Harbour Cheese       NS
# 1449                             Hip Hop       Blue Harbour Cheese       NS
# 1450            Super Fresh Cheese Curds   The Cheese Factory Ltd.       AB
#
#      Source_Type  FatContentPercent  MoisturePercent  \
# ...

# %%
#save progress in csv
#chz_fork.to_csv('./data/fork_and_bottle.csv', index=False)

# %%
#read cheese_posts.csv into 'chz_fork'
chz_fork = pd.read_csv('./data/fork_and_bottle.csv')

# %%
for i in range(len(can_chz)):
    for k in range(len(chz_fork)):
        if chz_fork['Name'][k] in can_chz['Name'][i]:
        #if can_chz['Name'][i] == chz_fork['Name'][k]:
            print(can_chz['Name'][i])
            print(chz_fork['Name'][k])
            print()
# Out:
# Comox Camembert
# Camembert
#
# Pecorino Fresco / Pepato Fresco
# Pepato
#
# Okanagan Double Cream Camembert
# Camembert
#
# Okanagan Double Cream Camembert
# Oka
#
# Chevre (Village Cheese)
# Chevre
#
# Chevre (Village Cheese)
# Chevre
#
# Caerphilly
# Caerphilly
#
# Triple Cream Camembert
# Camembert
#
# Pepato & Peperonato
# Pepato
#
# Okanagan Goat Cheese
# Oka
#
# Goat Milk Caerphilly
# Caerphilly
#
# Hand Rolled Chevre Logs
# Chevre
#
# Muenster
# Muenster
#
# Ash-Ripened Camembert
# Camembert
#
# Saumuré Coaticook
# Saumur
#
# Camembert de Portneuf
# Camembert
#
# Rondoux double crème
# Rondo
#
# Rondoux triple crème
# Rondo
#
# Rondoux pur chèvre
# Rondo
#
# Oka avec champignons
# Oka
#
# Oka l'artisan
# Oka
#
# Camembert Allégro
# Camembert
#
# Camembert Anco
# Camembert
#
# Grand Camembert l'Extra
# Camembert
#
# Grand Camembert Vaudreuil
# Camembert
#
# Camembert Provençal
# Camembert
#
# Camembert Gourmet
# Camembert
#
# Providence d'Oka (La)
# Oka
#
# ...

# %%
# function to strip strings of accents, from BartoszKP and oefe on StackOverflow
# https://stackoverflow.com/questions/517923/what-is-the-best-way-to-remove-accents-in-a-python-unicode-string

import unicodedata
def strip_accents(s):
   return ''.join(c for c in unicodedata.normalize('NFD', s)
                  if unicodedata.category(c) != 'Mn')

# %%
def has_same_cheese(df1, df2):
    count = 0

    for i in range(len(df1)):
        for k in range(len(df2)):
            if strip_accents(df2['Name'][k].lower()) in strip_accents(df1['Name'][i].lower()):
            #if df1['Name'][i] == df2['Name'][k]:
                count += 1
                print(df1['Name'][i])
                print(df2['Name'][k])
                print()
                
    print(f"The first dataset had {count} cheeses that were in the second dataset.")

# %%
has_same_cheese(can_chz, chz_fork)
# Out:
# Madame Chèvre Elite
# Chevre
#
# Comox Camembert
# Camembert
#
# Pecorino Fresco / Pepato Fresco
# Pepato
#
# Okanagan Double Cream Camembert
# Camembert
#
# Okanagan Double Cream Camembert
# Oka
#
# Chevre (Village Cheese)
# Chevre
#
# Chevre (Village Cheese)
# Chevre
#
# Caerphilly
# Caerphilly
#
# Triple Cream Camembert
# Camembert
#
# Pepato & Peperonato
# Pepato
#
# Okanagan Goat Cheese
# Oka
#
# Fresh Chèvre
# Chevre
#
# Goat Milk Caerphilly
# Caerphilly
#
# Hand Rolled Chevre Logs
# Chevre
#
# Muenster
# Muenster
#
# Chèvre (Goat's Pride)
# Chevre
#
# Tomme de chèvre (Goat's Pride)
# Chevre
#
# Ash-Ripened Camembert
# Camembert
#
# Chèvre Cheeses (Salt Spring Island)
# Chevre
#
# Saumuré Coaticook
# Saumur
#
# Fromage en grains la Chèvrerie Barrousse
# Chevre
#
# Chèvre frais fermier
# Chevre
#
# Chèvre-Naud (Le)
# Chevre
#
# Camembert de Portneuf
# Camembert
#
# Chèvre D'Art
# Chevre
#
# Chèvre des neiges
# Chevre
#
# Paillot de chèvre
# Chevre
#
# Chèvre-Noît Bleu de chèvre
# ...

# %%
has_same_cheese(chz_fork, can_chz)
# Out:
# Affidelice
# Délice
#
# Burrata
# Burrata
#
# Caerphilly
# Caerphilly
#
# Chabichou du Poitou
# Chabichou
#
# Chevre
# Chèvre
#
# Daisy Cheddar
# Cheddar
#
# Daisy Cheddar
# Cheddar
#
# Fiscalini Farmstead Cheddar
# Cheddar
#
# Fiscalini Farmstead Cheddar
# Cheddar
#
# Fleur de Chevre
# Chèvre
#
# Green's Raw Milk Farmhouse Cheddar
# Cheddar
#
# Green's Raw Milk Farmhouse Cheddar
# Cheddar
#
# Haystack Boulder Chevre
# Chèvre
#
# Isle of Mull Cheddar
# Cheddar
#
# Isle of Mull Cheddar
# Cheddar
#
# La Carre de Pere Antoine Mirabelle
# Belle
#
# Mascaret
# Mascaret
#
# Mozzarella di Capra
# Mozzarella
#
# Muenster
# Muenster
#
# Nicolau Farms Chevre
# Chèvre
#
# O'Banon
# Banon
#
# Oka
# Oka
#
# Picolo
# Pico
#
# Pug's Leap Chevre
# Chèvre
#
# Quicke's Farmhouse Cheddar
# Cheddar
#
# Quicke's Farmhouse Cheddar
# Cheddar
#
# Red Spruce (Cheddar)
# Cheddar
#
# Red Spruce (Cheddar)
# Cheddar
#
# Sugarbush Cheddar
# Cheddar
#
# Sugarbush Cheddar
# Cheddar
#
# Torta Ambrose
# Rose
#
# ...

# %%
has_same_cheese(chz_df3, can_chz)
# Out:
# Acapella
# Capella
#
# ADL Mild Cheddar
# Cheddar
#
# ADL Mild Cheddar
# Cheddar
#
# Affidelice au Chablis
# Délice
#
# Aged British Cheddar
# Cheddar
#
# Aged British Cheddar
# Cheddar
#
# Aged Gouda
# Gouda
#
# Amsterdammer (British Columbia)
# Amsterdammer
#
# Amul Gouda
# Gouda
#
# Amul Pizza Mozzarella Cheese
# Mozzarella
#
# Anniversary Ale Cheddar
# Cheddar
#
# Anniversary Ale Cheddar
# Cheddar
#
# Anthotyro Fresco
# Fresco
#
# Applewood Smoked Chevre
# Chèvre
#
# Ardsallagh Hard Goat's Cheese
# Hard Goat
#
# Aura
# Aura
#
# Avonlea Clothbound Cheddar
# Avonlea Clothbound Cheddar
#
# Avonlea Clothbound Cheddar
# Cheddar
#
# Avonlea Clothbound Cheddar
# Cheddar
#
# Baby Swiss
# Swiss
#
# Baluchon
# Baluchon
#
# Banon
# Banon
#
# Barambah Organics Marinated Feta
# Feta
#
# Barrel Aged Feta
# Feta
#
# Barry's Bay Cheddar
# Cheddar
#
# Barry's Bay Cheddar
# Cheddar
#
# Bega Processed Cheddar
# Cheddar
#
# Bega Processed Cheddar
# Cheddar
#
# Belle Creme
# Belle
#
# Belle Creme
# ...

# %%
chz_df3[chz_df3['Name'] == 'Grey Owl']
# Out:
#          Name Made from Country of origin                     Region Family  \
# 762  Grey Owl       NaN            Canada  Notre-Dame-du-Lac, Québec    NaN
#
#               Type Fat content Calcium content  \
# 762  soft, artisan         NaN             NaN
#
#                              Texture     Rind Colour               Flavour  \
# 762  creamy, crumbly, dense and firm  natural  white  lemony, sharp, tangy
#
#             Aroma Vegetarian             Producers
# 762  fresh, goaty       yes   Fromagerie Le Detour

# %%
can_chz[can_chz['Name'] == 'Grey Owl']
# Out:
#           Name          Manufacturer Provence Source_Type  FatContentPercent  \
# 1029  Grey Owl  Fromagerie Le Détour       QC     Artisan               24.0
#
#       MoisturePercent Rando_Details Flavor  \
# 1029             57.0           NaN   Mild
#
#                                 Characteristics                Age  Organic  \
# 1029  Ash rind with a chalky and creamy texture  Less than 1 Month        0
#
#          Category Animal  Raw_or_Past         Rind
# 1029  Soft Cheese   Goat  Pasteurized  Bloomy Rind

# %%
chz_fork
# Out:
#                              Name   Milk  Region  \
# 0                Abbaye de Belloc  sheep      FR
# 1               Abbaye de Citeaux  cow/R      FR
# 2                 Abbaye de Tamie    cow      FR
# 3                       Acappella   goat  CA, US
# 4                      Affidelice    cow      FR
# ..                            ...    ...     ...
# 360                    Wildmannli    cow      CH
# 361  Winchester Gouda -Super Aged  cow/p  CA, US
# 362                     Winnemere  cow/r  VT, US
# 363                  Wyfe of Bath  cow/R     ENG
# 364                      Zamarano  sheep      SP
#
#                                            Description
# 0    From the Pyrenees. Probably the cheese most re...
# 1    Produced by the monks of the Abbey of Saint Ni...
# 2    Similar to Reblochon but larger - a pressed un...
# 3    Andante in Petaluma, CA. A small cheese with a...
# 4    Made by Berthaudt in Burgundy. A washed rind c...
# ...

# %%
eda(chz_fork)
# Out:
# missing values:
# Name           0
# Milk           1
# Region         0
# Description    0
# dtype: int64
#
# dataframe index:
# RangeIndex(start=0, stop=365, step=1)
#
# dataframe types:
# Name           object
# Milk           object
# Region         object
# Description    object
# dtype: object
#
# dataframe shape:
# (365, 4)
#
# dataframe describe:
#               Name Milk Region              Description
# count          365  364    365                      365
# unique         362   34     43                      357
# top     Green Hill  cow     FR  From Pascal Beillevaire
# freq             2  136    124                        9
#
# number of unique values in each column:
# Name
# 362
# Milk
# 34
# Region
# 43
# Description
# 357

# %%
chz_fork[chz_fork['Milk'].isnull()]
# Out:
#            Name Milk Region             Description
# 211  Moncenisio  NaN     IT  see Bleu de Moncenisio

# %%
# according to https://culturecheesemag.com/cheese-library/blu-del-moncenisio, Moncenisio is made from cow milk
chz_fork[chz_fork['Name'] == 'Moncenisio']['Milk'] = 'cow'
# Out:
# /Users/michaelknight/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
chz_fork[chz_fork['Name'] == 'Moncenisio'] = chz_fork[chz_fork['Name'] == 'Moncenisio'].fillna('cow')

# %%
chz_fork[chz_fork['Name'] == 'Moncenisio']
# Out:
#            Name Milk Region             Description
# 211  Moncenisio  cow     IT  see Bleu de Moncenisio

# %%
eda(chz_fork)
# Out:
# missing values:
# Name           0
# Milk           0
# Region         0
# Description    0
# dtype: int64
#
# dataframe index:
# RangeIndex(start=0, stop=365, step=1)
#
# dataframe types:
# Name           object
# Milk           object
# Region         object
# Description    object
# dtype: object
#
# dataframe shape:
# (365, 4)
#
# dataframe describe:
#               Name Milk Region              Description
# count          365  365    365                      365
# unique         362   34     43                      357
# top     Green Hill  cow     FR  From Pascal Beillevaire
# freq             2  137    124                        9
#
# number of unique values in each column:
# Name
# 362
# Milk
# 34
# Region
# 43
# Description
# 357

# %%
#read culture_cheese_mag.csv into 'culture_chz'
culture_chz = pd.read_csv('./data/culture_cheese_mag.csv')

# %%
culture_chz
# Out:
#                                  Name                           Producer  \
# 0                    Abbaye de Belloc     Abbaye de Notre-Dame de Belloc
# 1                   Abbaye de Citeaux        Frère Joel & Frère Frédéric
# 2                     Abbaye de Tamie                     Monks of Tamie
# 3             Abbaye du Mont des Cats            Abbaye du Mont des Cats
# 4                           Abondance                            Various
# ...                               ...                                ...
# 1239  Camembert (Marin French Cheese)           Marin French Cheeese Co.
# 1240                  Za'atar Burrata                     Fiore di Nonno
# 1241                         Zamorano                            Various
# 1242                     Zelu Koloria                            Various
# 1243                 Ziege Zacke Blue  Roelli Cheese Haus / LaClare Farm
#
#             Country              Region                             Size  \
# ...

# %%
# it looks like the info given in the 'Flavor' column in this data set is useless except for telling whether or
# not the cheese is smoked, so I decided to extract whether a cheese was smoked or not, make a new column out
# of that info (called 'Smoked'), and then drop the Flavor column
culture_chz['Flavor'].unique()
# Out:
# array(['Flavor added to rind', nan, 'Flavor added to paste', 'Smoked',
#        'Flavor added to rindSmoked',
#        'Flavor added to pasteFlavor added to rind',
#        'Flavor added to pasteSmoked'], dtype=object)

# %%
# because NaN's read like floats, they mess up the loop, so I had to convert them to strings
culture_chz['Flavor'].fillna('empty', inplace=True)

# %%
list = []
for i in range(len(culture_chz)):
    if "Smoked" in culture_chz['Flavor'][i]:
        name = culture_chz['Name'][i]
        list.append(name)
list
# Out:
# ['Airco',
#  'Apple Smoked Cheddar',
#  'Appletree Smoked Cheddar',
#  'Braided String Cheese - Hickory Smoked (Karoun)',
#  'Cascaval',
#  'Chechil',
#  'Cheddar (Gold Creek Smoked White)',
#  'Cheddar (Quickes Smoked)',
#  'Cheddar (Shelburne Smoked)',
#  'Frère Fumant',
#  'Jersey Jack',
#  'Maple Smoked Cheddar (Grafton Village)',
#  'Scamorza - Smoked (The Mozzarella Company)',
#  'Smoked Baby Swiss',
#  'Smoked Chili Cheddar (Grafton)',
#  'Smoked Gouda (Brazos Valley)',
#  'Smoked Kentucky Bleu',
#  'Smoked Parmesan (Gold Creek)',
#  'Smoked Provolone (Silvery Moon Creamery)',
#  'Smoking Goud',
#  'Up in Smoke',
#  'Up North Smoked Ricotta']

# %%
culture_chz.iloc[0]["Flavor"]
# Out:
# 'Flavor added to rind'

# %%
for i in range(len(culture_chz)):
    if "Smoked" in culture_chz['Flavor'][i]:
        culture_chz['Smoked'][i] = 1
    else:
        culture_chz['Smoked'][i] = 0
# Out:
# /Users/michaelknight/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/michaelknight/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# drop Flavor column
culture_chz.drop(columns=['Flavor'], inplace=True)

# %%
# drop other features that are useless to this project
culture_chz.drop(columns=['Size', 'Website', 'Weight'], inplace=True)

# %%
culture_chz[culture_chz['Smoked'] == 1]
# Out:
#                                                  Name  \
# 9                                               Airco
# 25                               Apple Smoked Cheddar
# 26                           Appletree Smoked Cheddar
# 135   Braided String Cheese - Hickory Smoked (Karoun)
# 224                                          Cascaval
# 256                                           Chechil
# 278                 Cheddar (Gold Creek Smoked White)
# 287                          Cheddar (Quickes Smoked)
# 291                        Cheddar (Shelburne Smoked)
# 526                                      Frère Fumant
# 658                                       Jersey Jack
# 737            Maple Smoked Cheddar (Grafton Village)
# 1022       Scamorza - Smoked (The Mozzarella Company)
# 1054                                Smoked Baby Swiss
# 1056                   Smoked Chili Cheddar (Grafton)
# 1058                     Smoked Gouda (Brazos Valley)
# ...

# %%
culture_chz
# Out:
#                                  Name                           Producer  \
# 0                    Abbaye de Belloc     Abbaye de Notre-Dame de Belloc
# 1                   Abbaye de Citeaux        Frère Joel & Frère Frédéric
# 2                     Abbaye de Tamie                     Monks of Tamie
# 3             Abbaye du Mont des Cats            Abbaye du Mont des Cats
# 4                           Abondance                            Various
# ...                               ...                                ...
# 1239  Camembert (Marin French Cheese)           Marin French Cheeese Co.
# 1240                  Za'atar Burrata                     Fiore di Nonno
# 1241                         Zamorano                            Various
# 1242                     Zelu Koloria                            Various
# 1243                 Ziege Zacke Blue  Roelli Cheese Haus / LaClare Farm
#
#             Country              Region     Milk    Treatment Classification  \
# ...

# %%
eda(culture_chz)
# Out:
# missing values:
# Name                0
# Producer           31
# Country            35
# Region             12
# Milk                5
# Treatment         680
# Classification     19
# Rennet             45
# Rind               30
# Style             703
# Description         0
# Smoked              0
# dtype: int64
#
# dataframe index:
# RangeIndex(start=0, stop=1244, step=1)
#
# dataframe types:
# Name              object
# Producer          object
# Country           object
# Region            object
# Milk              object
# Treatment         object
# Classification    object
# Rennet            object
# Rind              object
# Style             object
# Description       object
# Smoked             int64
# dtype: object
#
# dataframe shape:
# (1244, 12)
#
# dataframe describe:
#             Smoked
# count  1244.000000
# mean      0.017685
# std       0.131856
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000
#
# ...

# %%
culture_chz['Rennet'].unique()
# Out:
# array(['Animal', 'Vegetable', 'Microbial', nan, 'True Vegetable',
#        'AnimalMicrobial', 'Chymosin', 'VegetableAnimal'], dtype=object)

# %%
culture_chz['Style'].unique()
# Out:
# array(['Alpine-styleCheddar-like', 'Soft-Ripened (Brie-like)Washed-Rind',
#        'Washed-Rind', 'Alpine-styleWashed-Rind', 'Alpine-style',
#        'Soft-Ripened (Brie-like)', 'Cheddar-like',
#        'Alpine-styleGouda-likeWashed-Rind', 'Washed-RindAlpine-style',
#        'Blue', 'Grana / Grating cheese', nan, 'Fresh',
#        'Alpine-styleSoft-Ripened (Brie-like)',
#        'Pasta Filata (mozzarella-type)',
#        'Alpine-styleCheddar-likeGrana / Grating cheese',
#        'CrèmeWashed-Rind',
#        'Cheddar-likeGouda-likeGrana / Grating cheeseWashed-Rind',
#        'BlueCheddar-like', 'Gouda-likeGrana / Grating cheese',
#        'Cheddar-likeWashed-Rind', 'Cheddar-likeGrana / Grating cheese',
#        'BlueSoft-Ripened (Brie-like)',
#        'Alpine-styleCheddar-likeGouda-like', 'Alpine-styleBlue',
#        'Gouda-like', 'CrèmeSoft-Ripened (Brie-like)',
#        'FreshPasta Filata (mozzarella-type)', 'Crème', 'BlueCrème',
# ...

# %%
culture_chz['Treatment'].unique()
# Out:
# array(['Raw', nan, 'Pasteurised', 'Heat Treated', 'PasteurisedRaw',
#        'Thermalised'], dtype=object)

# %%
culture_chz['Treatment'].unique()

# %%
culture_chz['Classification'].unique()
# Out:
# array(['Firm', 'Semi Soft', 'Soft', 'Hard', 'BlueSemi Soft', 'BlueFirm',
#        'FirmHard', 'Semi SoftBlue', 'FirmBlue', 'Blue', nan,
#        'Flavor AddedSemi Soft', 'BlueSoft', 'Flavor Added',
#        'SoftFlavor Added', 'Semi SoftFirm', 'Semi SoftFirmHard',
#        'Flavor AddedFirm', 'Semi SoftFlavor Added', 'FirmFlavor Added'],
#       dtype=object)

# %%
# since there are only 5 cheeses in this list with missing Milk type, I decided to manually look them up!
culture_chz[culture_chz['Milk'].isnull()]
# Out:
#                                  Name                    Producer  \
# 518  Fromage Blanc (Cowgirl Creamery)            Cowgirl Creamery
# 761                 Melkbus125 Winter  Uniekaas with De Producent
# 956         Ricotta (Caputo Brothers)   Caputo Brother’s Creamery
# 966       Ricotta Salata (BelGioioso)       BelGioioso Cheese Co.
# 968               Riesling x Sylvaner                BonCas Dairy
#
#            Country        Region Milk Treatment Classification     Rennet  \
# 518  United States    California  NaN       NaN           Soft  Microbial
# 761    Netherlands         Gouda  NaN       NaN            NaN        NaN
# 956  United States  Pennsylvania  NaN       NaN           Soft        NaN
# 966  United States     Wisconsin  NaN       NaN      Semi Soft        NaN
# 968    Switzerland      Dotzigen  NaN       NaN           Soft     Animal
#
#              Rind Style                                        Description  \
# ...

# %%
mask = culture_chz['Name'] == 'Fromage Blanc (Cowgirl Creamery)'

culture_chz[mask] = culture_chz[mask].fillna({'Milk' :'Cow', 'Treatment': 'Pasteurised'})

#culture_chz[culture_chz['Name'] == 'Fromage Blanc (Cowgirl Creamery)'].iloc[0][['Milk']] = culture_chz[culture_chz['Name'] == 'Fromage Blanc (Cowgirl Creamery)'].iloc[0][['Milk']].fillna("Cow")

# %%
culture_chz[culture_chz['Name'] == 'Fromage Blanc (Cowgirl Creamery)']
# Out:
#                                  Name          Producer        Country  \
# 518  Fromage Blanc (Cowgirl Creamery)  Cowgirl Creamery  United States
#
#          Region Milk    Treatment Classification     Rennet  Rind Style  \
# 518  California  Cow  Pasteurised           Soft  Microbial  None   NaN
#
#                                            Description  Smoked
# 518  Cowgirl Creamery, based in Marin County, Calif...       0

# %%
# found info on Cowgirl Creamery's Fromage Blanc by googling it (fun fact:  i used to work there in 2008!)
# found not only the milk type but Treatment info as well (it's pasteurized)
# https://www.cowgirlcreamery.com/library-of-cheese/fromage-blanc

mask = culture_chz['Name'] == 'Fromage Blanc (Cowgirl Creamery)'

culture_chz[mask] = culture_chz[mask].fillna({'Milk' :'Cow', 'Treatment': 'Pasteurised'})

# %%
# found info on Melkbus125 Winter by googling it 
# found not only the milk type but Treatment info as well (it's raw), and rennet type
# since it's gouda can deduce that style is gouda-like and classification is firm
# http://uniekaasusa.com/cheeses/melkbus-winter-2/


mask = culture_chz['Name'] == 'Melkbus125 Winter'

culture_chz[mask] = culture_chz[mask].fillna({'Milk' :'Cow', 'Treatment': 'Pasteurised', 'Rennet' :'Animal', 
                                              'Style': 'Gouda-like', 'Classification': 'Firm'})

# %%
# found info on Ricotta (Caputo Brothers) by googling it 
# found not only the milk type but Treatment, Style and Rennet
# https://caputobrotherscreamery.com/product/whey-based-ricotta/

mask = culture_chz['Name'] == 'Ricotta (Caputo Brothers)'

culture_chz[mask] = culture_chz[mask].fillna({'Milk' :'Cow', 'Treatment': 'Pasteurised', 'Rennet' :'Animal', 
                                              'Style': 'Fresh'})

# %%
# found info on Ricotta Salata (BelGioioso) by googling it 
# found not only the milk type but Treatment, Style, and Rennet
# https://www.belgioioso.com/Products/Ricotta-Salata

mask = culture_chz['Name'] == 'Ricotta Salata (BelGioioso)'

culture_chz[mask] = culture_chz[mask].fillna({'Milk' :'Cow', 'Treatment': 'Pasteurised', 'Rennet' :'Vinegar', 
                                              'Style': 'Feta-like'})

# %%
# found info on Riesling x Sylvaner by googling it 
# found not only the milk type but Treatment info as well (it's raw)
# https://caputobrotherscreamery.com/product/whey-based-ricotta/


mask = culture_chz['Name'] == 'Riesling x Sylvaner'

culture_chz[mask] = culture_chz[mask].fillna({'Milk' :'Cow', 'Treatment': 'Pasteurised', 
                                              'Style': 'Soft-Ripened (Brie-like)'})

# %%
eda(culture_chz)
# Out:
# missing values:
# Name                0
# Producer           31
# Country            35
# Region             12
# Milk                0
# Treatment         675
# Classification     18
# Rennet             42
# Rind               30
# Style             699
# Description         0
# Smoked              0
# dtype: int64
#
# dataframe index:
# RangeIndex(start=0, stop=1244, step=1)
#
# dataframe types:
# Name              object
# Producer          object
# Country           object
# Region            object
# Milk              object
# Treatment         object
# Classification    object
# Rennet            object
# Rind              object
# Style             object
# Description       object
# Smoked             int64
# dtype: object
#
# dataframe shape:
# (1244, 12)
#
# dataframe describe:
#             Smoked
# count  1244.000000
# mean      0.017685
# std       0.131856
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000
#
# ...

# %%
len(can_chz)
# Out:
# 1451

# %%
len(chz_df3)
# Out:
# 1828

# %%
len(culture_chz)
# Out:
# 1244

# %%
has_same_cheese(chz_df3, culture_chz)
# Out:
# Abbaye de Belloc
# Abbaye de Belloc
#
# Abbaye de Citeaux
# Abbaye de Citeaux
#
# Abbaye du Mont des Cats
# Abbaye du Mont des Cats
#
# Abondance
# Abondance
#
# Acapella
# Acapella
#
# ADL Brick Cheese
# Brick
#
# Allgauer Emmentaler
# Emmentaler
#
# Almnäs Tegel
# Almnäs Tegel
#
# Alpha Tolman
# Alpha Tolman
#
# Alpine Gold
# Alpine Gold
#
# Ameribella
# Ameribella
#
# Appalachian
# Appalachian
#
# Appenzeller
# Appenzeller
#
# Ardrahan
# Ardrahan
#
# Ascutney Mountain
# Ascutney Mountain
#
# Asher Blue
# Asher Blue
#
# Ashley
# Ashley
#
# Assa
# Assa
#
# Avonlea Clothbound Cheddar
# Avonlea Clothbound
#
# Azeitao
# Azeitão
#
# Bad Axe
# Bad Axe
#
# Banon
# Banon
#
# Barambah Organics Marinated Feta
# Marinated Feta
#
# Barambah Organics Marinated Feta
# Ted
#
# Barely Buzzed
# Barely Buzzed
#
# Barilotto
# Barilotto
#
# Bayley Hazen Blue
# Bayley Hazen Blue
#
# Bear Hill
# Bear Hill
#
# Beenleigh Blue
# Beenleigh Blue
#
# Bellwether Farms Crescenza
# Crescenza
#
# Benedictine
# ...

# %%
has_same_cheese(culture_chz, chz_df3)
# Out:
# Abbaye de Belloc
# Abbaye de Belloc
#
# Abbaye de Citeaux
# Abbaye de Citeaux
#
# Abbaye de Tamie
# Tamie
#
# Abbaye du Mont des Cats
# Abbaye du Mont des Cats
#
# Abondance
# Abondance
#
# Acapella
# Acapella
#
# Adams Reserve Cheddar
# Cheddar
#
# Aged Cheddar (Grafton)
# Cheddar
#
# Almnäs Tegel
# Almnäs Tegel
#
# Alpha Tolman
# Alpha Tolman
#
# Alpine Gold
# Alpine Gold
#
# Alpine Style (Kennebec)
# Kenne
#
# Ameribella
# Ameribella
#
# American Grana
# Grana
#
# Ancho Goat Caciotta
# Caciotta
#
# Appalachian
# Appalachian
#
# Appenzeller
# Appenzeller
#
# Apple Smoked Cheddar
# Cheddar
#
# Appletree Smoked Cheddar
# Cheddar
#
# Ardrahan
# Ardrahan
#
# Arzúa Ulloa
# Ulloa
#
# Ascutney Mountain
# Ascutney Mountain
#
# Asher Blue
# Asher Blue
#
# Ashley
# Ashley
#
# Asiago d'Allevo
# Asiago
#
# Asiago (Sartori)
# Asiago
#
# Assa
# Assa
#
# Azeitão
# Azeitao
#
# Baby Swiss (Boggy Meadow)
# Baby Swiss
#
# Baby Swiss (Boggy Meadow)
# Swiss
#
# Bad Axe
# Bad Axe
#
# Banon
# Banon
#
# ...

# %%
has_same_cheese(culture_chz, can_chz)
# Out:
# Acapella
# Capella
#
# Adams Reserve Cheddar
# Cheddar
#
# Adams Reserve Cheddar
# Cheddar
#
# Aged Cheddar (Grafton)
# Cheddar
#
# Aged Cheddar (Grafton)
# Cheddar
#
# Apple Smoked Cheddar
# Cheddar
#
# Apple Smoked Cheddar
# Cheddar
#
# Appletree Smoked Cheddar
# Cheddar
#
# Appletree Smoked Cheddar
# Cheddar
#
# Baby Swiss (Boggy Meadow)
# Swiss
#
# Banon
# Banon
#
# Bleu Benedictine
# Bleu Bénédictin
#
# Brie Paysan
# Brie Paysan
#
# Bucheron (Montchevré)
# Chèvre
#
# Buffalo Mozzarella (Deca & Otto)
# Mozzarella
#
# Burrata (Belgioioso)
# Burrata
#
# Burrata (Deca & Otto)
# Burrata
#
# Burrata (Maplebrook Farm)
# Burrata
#
# Burrata (Mozzarella Co)
# Burrata
#
# Burrata (Mozzarella Co)
# Mozzarella
#
# Burwash Rose
# Rose
#
# Cabrie
# Cabrie
#
# Caerphilly (Gorwydd Farm)
# Caerphilly
#
# Caerphilly (Tonjes)
# Caerphilly
#
# Carmela
# Carmel
#
# Cave Aged Cheddar (Carr Valley)
# Cheddar
#
# Cave Aged Cheddar (Carr Valley)
# Cheddar
#
# Chabichou du Poitou PDO
# Chabichou
#
# ...

# %%
has_same_cheese(can_chz, culture_chz)
# Out:
# Provolone Sette Fette (Tre-Stelle)
# Provolone
#
# Udderly Organic Goat Gouda (Jerseyland Organic)
# Goat Gouda
#
# Provolone (Silani)
# Provolone
#
# Cheddars (Fromagerie St-Albert)
# Oma
#
# Banon
# Banon
#
# Pecorino Fresco / Pepato Fresco
# Pepato
#
# Halloumi
# Halloumi
#
# Mozzarella (Amalgamated Dairies Ltd.)
# Ted
#
# Brick (Amalgamated Dairies Ltd)
# Brick
#
# Brick (Amalgamated Dairies Ltd)
# Ted
#
# Colby (Amalgamated Dairies Ltd.)
# Ted
#
# Cheddar (Amalgamated Dairies Limited)
# Ted
#
# Monterey Jack (Amalgamated Dairies)
# Ted
#
# Farmers (Amalgamated Dairies Ltd)
# Ted
#
# Okanagan Double Cream Camembert
# Oka
#
# Harvest Moon
# Harvest
#
# Brick (Village Cheese)
# Brick
#
# Raclette (Little Qualicum)
# Raclette
#
# Romano (Silani)
# Oma
#
# Élan (L') (Fromagerie St-Albert)
# Oma
#
# Brick (Tre Stelle)
# Brick
#
# Shredded Parmesan with Romano Cheese
# Oma
#
# Pepato & Peperonato
# Pepato
#
# Provolone (Tre Stelle)
# Provolone
#
# Okanagan Goat Cheese
# Oka
#
# ...

# %%
eda(chz_df3)
# Out:
# missing values:
# Name                    0
# Made from              55
# Country of origin      17
# Region                238
# Family               1034
# Type                   24
# Fat content          1235
# Calcium content      1780
# Texture               105
# Rind                  238
# Colour                175
# Flavour                94
# Aroma                 354
# Vegetarian            527
# Producers             402
# dtype: int64
#
# dataframe index:
# RangeIndex(start=0, stop=1828, step=1)
#
# dataframe types:
# Name                 object
# Made from            object
# Country of origin    object
# Region               object
# Family               object
# Type                 object
# Fat content          object
# Calcium content      object
# Texture              object
# Rind                 object
# Colour               object
# Flavour              object
# Aroma                object
# Vegetarian           object
# Producers            object
# ...

# %%
np.nan
# Out:
# nan

# %%
chz_df3.head()
# Out:
#                       Name                             Made from  \
# 0         Abbaye de Belloc  unpasteurized cow's and sheep's milk
# 1         Abbaye de Belval                            cow's milk
# 2        Abbaye de Citeaux              unpasteurized cow's milk
# 3       Abbaye de Timadeuc                pasteurized cow's milk
# 4  Abbaye du Mont des Cats                pasteurized cow's milk
#
#   Country of origin                 Region Family                        Type  \
# 0            France            Pays Basque    NaN          semi-hard, artisan
# 1            France                    NaN    NaN                   semi-hard
# 2            France               Burgundy    NaN  semi-soft, artisan, brined
# 3            France   province of Brittany    NaN                   semi-hard
# 4            France     Nord-Pas-de-Calais    NaN  semi-soft, artisan, brined
#
#   Fat content (in dry matter) Fat content Calcium content  \
# ...

# %%
chz_df3['Fat content'].unique()
# Out:
# array([nan, '40-46%', '50%', '45%', '48%', '52%', '12%', '14%', '55%',
#        '59%', '31 g/100g', '34%', '33.5  g/100g', '40-50%', '45-60%',
#        '30%', '18-20%', '46%', '30-40%', '26%', '8%', '20%',
#        '54.23 g/100g', '25%', '34-48%', '40-45%', '10%', '32%', '43%',
#        '69%', '28.5%', '22%', '28%', '25.22 g/100g', '20-30%', '11%',
#        '25.5%', '43.3-26.5 g/100g', '62%', '5 g/100g', '45-50%', '70%',
#        '15-25%', '39.6 g/100g', '32.5 g/100g', '40%', '37%', '54%',
#        '6 g/100g', ' 31%', '43.3 g/100g', '21%', '75%', '60%', '35%',
#        '7 g/100g', '8.4 g/100g', '27 g/100g', '46-60%', '8 g/100g', '67%',
#        '13%', '34.2 g/100g', '27%', '9 g/100g', '24%', '33%',
#        '4.30 g/100g', '65%', '11.0 g/100g', '51%', '31.0 g/100g',
#        '25-30%', '15-45%', '22-28 g/100g', '34.5 g/100g', '17%', '22 %',
#        '15%', '30.5%', '26-28%', '21 g/100g', '72%', '17.1 g/100g',
#        '14.6 g/100g', '22 g/100g', '10.1 g/100g', '16%', '1.0%',
# ...

# %%
Fat_list = []
for i in chz_df3['Fat content'].unique().tolist()[1:]:
    Fat_list.append(i.replace('%', '').replace('g', ''))

# %%
Fat_list
# Out:
# ['40-46',
#  '50',
#  '45',
#  '48',
#  '52',
#  '12',
#  '14',
#  '55',
#  '59',
#  '31 /100',
#  '34',
#  '33.5  /100',
#  '40-50',
#  '45-60',
#  '30',
#  '18-20',
#  '46',
#  '30-40',
#  '26',
#  '8',
#  '20',
#  '54.23 /100',
#  '25',
#  '34-48',
#  '40-45',
#  '10',
#  '32',
#  '43',
#  '69',
#  '28.5',
#  '22',
#  '28',
#  '25.22 /100',
#  '20-30',
#  '11',
#  '25.5',
#  '43.3-26.5 /100',
#  '62',
#  '5 /100',
#  '45-50',
#  '70',
#  '15-25',
#  '39.6 /100',
#  '32.5 /100',
#  '40',
#  '37',
#  '54',
#  '6 /100',
#  ' 31',
#  '43.3 /100',
#  '21',
#  '75',
#  '60',
#  '35',
#  '7 /100',
#  '8.4 /100',
#  '27 /100',
#  '46-60',
#  '8 /100',
#  '67',
#  '13',
#  '34.2 /100',
#  '27',
#  '9 /100',
#  '24',
#  '33',
#  '4.30 /100',
#  '65',
#  '11.0 /100',
#  '51',
#  '31.0 /100',
#  '25-30',
#  '15-45',
#  '22-28 /100',
#  '34.5 /100',
#  '17',
#  '22 ',
#  '15',
#  '30.5',
#  '26-28',
#  '21 /100',
#  '72',
#  '17.1 /100',
#  '14.6 /100',
#  '22 /100',
#  '10.1 /100',
#  '16',
# ...

# %%
new_list = []
for i in Fat_list:
    new_list.append(int(i))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-239-7784179b7638> in <module>
#       1 new_list = []
#       2 for i in Fat_list:
# ----> 3     new_list.append(int(i))
#
# ValueError: invalid literal for int() with base 10: '40-46'

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-241-bdf8b4176ecf> in <module>
# ----> 1 int('56-5')
#
# ValueError: invalid literal for int() with base 10: '56-5'
